# %%
import pandas as pd
import numpy as np
import urllib.request
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dr16_known.csv")
# Out:
#     Unnamed: 0                objid          ra        dec      g-i      u-g  \
# 0            0  1237654786779840539  187.376046   7.992843  1.23050  1.83839
# 1            1  1237654606410285099  184.846192   5.794837  1.22716  1.86846
# 2            2  1237661949719347370  188.905205  12.382046  1.16337  1.81895
# 3            3  1237655468598165525  226.642819   1.558828  1.33579  2.07764
# 4            4  1237661812812873761  187.633245  12.490215  1.23018  1.96878
# 5            5  1237654786779840584  187.395804   8.057988  1.30699  1.83986
# 6            6  1237658629695733921  187.970395  12.266407  0.98381  1.56026
# 7            7  1237661816022499458  190.480562  11.667721  1.17364  2.17913
# 8            8  1237658630232539222  187.799501  12.683631  1.06181  1.67339
# 9            9  1237661812812873762  187.639285  12.498435  0.85302  1.68729
# 10          10  1237661950255825006  187.882077  12.691753  0.93591  1.41815
# ...

# %%
df['ra'][1]
# Out:
# 184.84619203171

# %%
for i in range(len(df['objid'])):
    x = urllib.request.urlretrieve("""http://skyserver.sdss.org/dr16/SkyServerWS/ImgCutout/getjpeg?ra={}&dec={}&&scale=0.40&width=120&height=120&opt=""".format(df['ra'][i],df['dec'][i]),"""C:/Users/satin/OneDrive/AstroResearch/Refined research/DR16/images/{}.png""".format(df['objid'][i]))

# %%
plt.imshow(x)
# Out:
# C:\Users\satin\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:701: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   x = np.array(x, subok=True, copy=copy)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 plt.imshow(x)
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py:456, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     450 if len(args) > name_idx:
#     451     warn_deprecated(
#     452         since, message="Passing the %(name)s %(obj_type)s "
#     453         "positionally is deprecated since Matplotlib %(since)s; the "
# ...

# %%
x = urllib.request.urlretrieve("""http://skyserver.sdss.org/dr16/SkyServerWS/ImgCutout/getjpeg?ra={}&dec={}&&scale=0.40&width=120&height=120&opt=""".format(df['ra'][1],df['ra'][1]),"""C:/Users/satin/OneDrive/AstroResearch/Refined research/DR16/images/{}.png""".format(df['objid'][1]))

# %%
plt.show(x)

# %%
x
# Out:
# ('C:\\Users\\satin\\AppData\\Local\\Temp\\tmp77e8b576',
#  <http.client.HTTPMessage at 0x1bfa8a4f2b0>)

# %%
"""http://skyserver.sdss.org/dr16/SkyServerWS/ImgCutout/getjpeg?ra={}&dec={}&&scale=0.40&width=120&height=120&opt=""".format(ra,dec)
